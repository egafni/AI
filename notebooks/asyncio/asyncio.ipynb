# %%
urls="""https://regex101.com/
https://docs.python.org/3/this-url-will-404.html
https://www.nytimes.com/guides/
https://www.mediamatters.org/
https://1.1.1.1/
https://www.politico.com/tipsheets/morning-money
https://www.bloomberg.com/markets/economics
https://www.ietf.org/rfc/rfc2616.txt""".split()
import asyncio
import logging
import re
import sys
from typing import IO
import urllib.error
import urllib.parse

# import aiofiles
import aiohttp
from aiohttp import ClientSession
logger = logging.getLogger()

# %%
session = ClientSession()

# %%
HREF_RE = re.compile(r'href="(.*?)"')

# %%
def log(*x):
    logger.info(*x)

async def fetch_html(url, session):
    resp = await session.request(method='GET', url=url)
    resp.raise_for_status()
    log(f'url response: {resp.status}')
    html = await resp.text()
    return html
    
async def parse(url, session):
    found = set()
    try:
        html = await fetch_html(url, session)
    except (aiohttp.ClientError, aiohttp.http_exceptions.HttpProcessingError) as e:
        log(f'{url} exception: {e}')
        return found
    except Exception as e:
        log(f'{url} non aio exception: {e}')
        return found
    else:
        for link in HREF_RE.findall(html):
            try:
                abslink = urllib.parse.urljoin(url, link)
            except (urllib.error.URLError, ValueError):
                log(f"Error parsing URL: {link}")
                pass
            else:
                found.add(abslink)
        log(f"Found {len(found)} links for {url}")
        return found

# from asyn import partial
# tasks = [asyncio.create_task(parse(url, session)) for url in urls]

# %%
from concurrent.futures import ThreadPoolExecutor, ProcessPoolExecutor
loop = asyncio.get_running_loop()
# loop.run_forever()

results = []
for url in urls:
    r = await loop.run_in_executor(None, parse, url, session)
    results.append(r)

# %%
await asyncio.gather(*results)
# Out:
# [{'http://browsehappy.com/',
#   'http://whatismarkdown.com/',
#   'https://discord.gg/wUA6F6YqSs',
#   'https://fonts.googleapis.com',
#   'https://fonts.googleapis.com/css2?family=Open+Sans:ital,wght@0,300;0,400;0,600;0,700;1,400&family=Source+Code+Pro:wght@400;500;700&display=swap',
#   'https://fonts.gstatic.com',
#   'https://github.com/firasdib/Regex101/issues',
#   'https://github.com/firasdib/Regex101/wiki',
#   'https://github.com/sponsors/firasdib',
#   'https://regex101.com',
#   'https://regex101.com/',
#   'https://regex101.com/account/mine',
#   'https://regex101.com/codegen?language=php',
#   'https://regex101.com/debugger',
#   'https://regex101.com/library',
#   'https://regex101.com/quiz',
#   'https://regex101.com/settings',
#   'https://regex101.com/static/653.8eb7aa021aa1417c05e6.css',
#   'https://regex101.com/static/assets/10.2__iPad_landscape.png',
#   'https://regex101.com/static/assets/10.2__iPad_portrait.png',
#   'https://regex101.com/static/assets/10.5__iPad_Air_landscape.png',
#   'https://regex101.com/static/assets/10.5__iPad_Air_portrait.png',
#   'https://regex101.com/static/assets/10.9__iPad_Air_landscape.png',
#   'https://regex101.com/static/assets/10.9__iPad_Air_portrait.png',
#   'https://regex101.com/static/assets/11__iPad_Pro__10.5__iPad_Pro_landscape.png',
#   'https://regex101.com/static/assets/11__iPad_Pro__10.5__iPad_Pro_portrait.png',
#   'https://regex101.com/static/assets/12.9__iPad_Pro_landscape.png',
#   'https://regex101.com/static/assets/12.9__iPad_Pro_portrait.png',
#   'https://regex101.com/static/assets/4__iPhone_SE__iPod_touch_5th_generation_and_later_landscape.png',
#   'https://regex101.com/static/assets/4__iPhone_SE__iPod_touch_5th_generation_and_later_portrait.png',
#   'https://regex101.com/static/assets/8.3__iPad_Mini_landscape.png',
#   'https://regex101.com/static/assets/8.3__iPad_Mini_portrait.png',
#   'https://regex101.com/static/assets/9.7__iPad_Pro__7.9__iPad_mini__9.7__iPad_Air__9.7__iPad_landscape.png',
#   'https://regex101.com/static/assets/9.7__iPad_Pro__7.9__iPad_mini__9.7__iPad_Air__9.7__iPad_portrait.png',
#   'https://regex101.com/static/assets/changelog.md',
#   'https://regex101.com/static/assets/favicon.ico',
#   'https://regex101.com/static/assets/flavors.md',
#   'https://regex101.com/static/assets/iPhone_11_Pro_Max__iPhone_XS_Max_landscape.png',
#   'https://regex101.com/static/assets/iPhone_11_Pro_Max__iPhone_XS_Max_portrait.png',
#   'https://regex101.com/static/assets/iPhone_11__iPhone_XR_landscape.png',
#   'https://regex101.com/static/assets/iPhone_11__iPhone_XR_portrait.png',
#   'https://regex101.com/static/assets/iPhone_13_mini__iPhone_12_mini__iPhone_11_Pro__iPhone_XS__iPhone_X_landscape.png',
#   'https://regex101.com/static/assets/iPhone_13_mini__iPhone_12_mini__iPhone_11_Pro__iPhone_XS__iPhone_X_portrait.png',
#   'https://regex101.com/static/assets/iPhone_14_Plus__iPhone_13_Pro_Max__iPhone_12_Pro_Max_landscape.png',
#   'https://regex101.com/static/assets/iPhone_14_Plus__iPhone_13_Pro_Max__iPhone_12_Pro_Max_portrait.png',
#   'https://regex101.com/static/assets/iPhone_14_Pro_Max_landscape.png',
#   'https://regex101.com/static/assets/iPhone_14_Pro_Max_portrait.png',
#   'https://regex101.com/static/assets/iPhone_14_Pro_landscape.png',
#   'https://regex101.com/static/assets/iPhone_14_Pro_portrait.png',
#   'https://regex101.com/static/assets/iPhone_14__iPhone_13_Pro__iPhone_13__iPhone_12_Pro__iPhone_12_landscape.png',
#   'https://regex101.com/static/assets/iPhone_14__iPhone_13_Pro__iPhone_13__iPhone_12_Pro__iPhone_12_portrait.png',
#   'https://regex101.com/static/assets/iPhone_8_Plus__iPhone_7_Plus__iPhone_6s_Plus__iPhone_6_Plus_landscape.png',
#   'https://regex101.com/static/assets/iPhone_8_Plus__iPhone_7_Plus__iPhone_6s_Plus__iPhone_6_Plus_portrait.png',
#   'https://regex101.com/static/assets/iPhone_8__iPhone_7__iPhone_6s__iPhone_6__4.7__iPhone_SE_landscape.png',
#   'https://regex101.com/static/assets/iPhone_8__iPhone_7__iPhone_6s__iPhone_6__4.7__iPhone_SE_portrait.png',
#   'https://regex101.com/static/assets/icon-114.png',
#   'https://regex101.com/static/assets/icon-120.png',
#   'https://regex101.com/static/assets/icon-144.png',
#   'https://regex101.com/static/assets/icon-152.png',
#   'https://regex101.com/static/assets/icon-16.png',
#   'https://regex101.com/static/assets/icon-180.png',
#   'https://regex101.com/static/assets/icon-192.png',
#   'https://regex101.com/static/assets/icon-32.png',
#   'https://regex101.com/static/assets/icon-57.png',
#   'https://regex101.com/static/assets/icon-60.png',
#   'https://regex101.com/static/assets/icon-72.png',
#   'https://regex101.com/static/assets/icon-76.png',
#   'https://regex101.com/static/assets/icon-96.png',
#   'https://regex101.com/static/assets/manifest.webmanifest',
#   'https://regex101.com/static/bundle.130a4ec47225c8ad610e.css',
#   'https://regex101.com/static/quickref.4b83f44838633e3c70e8.chunk.js',
#   'https://turnonjs.com',
#   'https://twitter.com/regex101',
#   'https://web.libera.chat/?nick=re101-squid-?&amp;chan=#regex',
#   'https://www.paypal.com/donate/?hosted_button_id=83QZGPDJEX4MN',
#   'mailto:contact@regex101.com'},
#  set(),
#  set(),
#  {'https://action.mediamatters.org/secure/donate',
#   'https://fonts.googleapis.com/css?family=Barlow:400,400i,600,600i,700,700i',
#   'https://twitter.com/mmfa',
#   'https://use.typekit.net/jqh3ujo.css',
#   'https://www.facebook.com/Mediamatters/',
#   'https://www.instagram.com/mediamattersforamerica/',
#   'https://www.mediamatters.org/',
#   'https://www.mediamatters.org/#arrow',
#   'https://www.mediamatters.org/#article',
#   'https://www.mediamatters.org/#audio',
#   'https://www.mediamatters.org/#facebook',
#   'https://www.mediamatters.org/#instagram',
#   'https://www.mediamatters.org/#main-content',
#   'https://www.mediamatters.org/#narrative',
#   'https://www.mediamatters.org/#search',
#   'https://www.mediamatters.org/#study',
#   'https://www.mediamatters.org/#twitter',
#   'https://www.mediamatters.org/#video',
#   'https://www.mediamatters.org/#youtube',
#   'https://www.mediamatters.org/2020-election-lawsuits/cnn-marshall-cohen-reports-smartmatic-claims-oan-may-have-engaged-criminal',
#   'https://www.mediamatters.org/?page=0',
#   'https://www.mediamatters.org/?page=1',
#   'https://www.mediamatters.org/abortion-rights-and-reproductive-health',
#   'https://www.mediamatters.org/about',
#   'https://www.mediamatters.org/archives',
#   'https://www.mediamatters.org/audio-video',
#   'https://www.mediamatters.org/bret-baier/moments-after-his-show-reports-republicans-intentionally-stalled-border-deal-protect',
#   'https://www.mediamatters.org/carriage-fees/foxs-lachlan-murdoch-promises-use-sports-raise-your-cable-bill-learn-how-fight-back',
#   'https://www.mediamatters.org/carriage-fees/new-report-examines-how-fox-corp-leverages-sports-and-entertainment-force-cable',
#   'https://www.mediamatters.org/charlie-kirk/charlie-kirk-makes-false-accusations-about-exonerated-central-park-five-defendant-and',
#   'https://www.mediamatters.org/charlie-kirk/charlie-kirk-suggests-biden-would-be-blame-if-there-conflict-between-federal-and-state',
#   'https://www.mediamatters.org/charlie-kirk/right-wing-media-escalate-dei-panic-embrace-blatant-racism-against-black-pilots-and',
#   'https://www.mediamatters.org/climate-deniers/its-cold-outside-which-means-right-wing-media-are-going-their-annual-climate-denial',
#   'https://www.mediamatters.org/climate-deniers/what-gen-z-need-know-about-climate-denier-willie-soon',
#   'https://www.mediamatters.org/climate-energy',
#   'https://www.mediamatters.org/contact-us',
#   'https://www.mediamatters.org/corrections',
#   'https://www.mediamatters.org/crime-and-criminal-justice/bomb-threat-and-hate-speech-against-library-follow-targeted-harassment',
#   'https://www.mediamatters.org/critical-race-theory/heres-how-right-wing-media-are-attacking-americas-education-system',
#   'https://www.mediamatters.org/donald-trump/fox-news-maccallum-average-black-voters-dont-care-about-trumps-central-park-five',
#   'https://www.mediamatters.org/donald-trump/msnbc-angelo-carusone-discusses-lessons-media-need-learn-covering-trump',
#   'https://www.mediamatters.org/donald-trump/trumps-claims-immunity-have-been-disputed-maga-figures-and-other-republicans',
#   'https://www.mediamatters.org/fox-business/dejected-larry-kudlow-gives-begrudging-update-record-high-stock-market',
#   'https://www.mediamatters.org/fox-news/200-things-fox-news-has-labeled-woke',
#   'https://www.mediamatters.org/fox-news/fox-news-aiding-fossil-fuel-funded-campaign-targeting-offshore-wind',
#   'https://www.mediamatters.org/fox-news/fox-news-buried-story-texas-woman-prevented-getting-emergency-abortion',
#   'https://www.mediamatters.org/fox-news/fox-news-falsely-claimed-airports-are-allowing-migrants-through-security-without',
#   'https://www.mediamatters.org/fox-news/fox-news-guest-rick-perry-says-immigrants-dilute-america-and-people-should-be-arms',
#   'https://www.mediamatters.org/fox-news/fox-news-newt-gingrich-uses-ongoing-mass-shooting-maine-push-less-restrictive-gun-laws',
#   'https://www.mediamatters.org/fox-news/sean-hannity-says-he-discounted-trumps-stock-market-performance-he-did-when-it-fell',
#   'https://www.mediamatters.org/fox-news/virulent-antisemite-tells-jeanine-pirro-2nd-amendment-needed-take-care-these-vermin-who',
#   'https://www.mediamatters.org/google/youtube-monetizing-and-helping-raise-funds-patrick-casey-white-nationalist-whose-group',
#   'https://www.mediamatters.org/guns-public-safety',
#   'https://www.mediamatters.org/immigration/right-wing-media-escalate-civil-war-rhetoric-after-supreme-court-rules-against-texas',
#   'https://www.mediamatters.org/immigration/right-wing-media-figures-fearmonger-about-imminent-civil-war-after-supreme-court',
#   'https://www.mediamatters.org/immigration/right-wing-media-figures-rally-behind-take-our-border-back-convoy-which-organized',
#   'https://www.mediamatters.org/job-openings',
#   'https://www.mediamatters.org/lgbtq',
#   'https://www.mediamatters.org/live-action/anti-abortion-media-attacked-texas-woman-seeking-emergency-abortion-likening-procedure',
#   'https://www.mediamatters.org/matt-walsh/matt-walsh-flouted-youtube-guidelines-anti-lgbtq-hate-after-being-stripped-advertiser',
#   'https://www.mediamatters.org/matt-walsh/san-bernardino-pride-flag-murderer-and-inevitable-consequences-right-wing-media-hate',
#   'https://www.mediamatters.org/news-analysis',
#   'https://www.mediamatters.org/privacy',
#   'https://www.mediamatters.org/qanon-conspiracy-theory/conspiracy-theorist-brenden-dilley-got-press-passes-trump-campaigns-iowa',
#   'https://www.mediamatters.org/rumble/video-russell-brand-and-conspiracy-grift',
#   'https://www.mediamatters.org/sean-hannity/donald-trump-cites-sean-hannitys-asinine-border-prediction',
#   'https://www.mediamatters.org/sean-hannity/now-joe-biden-president-sean-hannity-doesnt-find-record-high-stock-market-all',
#   'https://www.mediamatters.org/sean-hannity/sean-hannity-blames-joe-biden-creating-rebellion-southern-border',
#   'https://www.mediamatters.org/search',
#   'https://www.mediamatters.org/sites/default/files/css/css_RU1WYR7X70QjhvL62_lE-Mmsn10zn8D85_M4ztVfCCs.css',
#   'https://www.mediamatters.org/sites/default/files/css/css_oGZ7OLJDM4FApNs8xyoZMUIkjUZCXrNP16OA9NXAcMA.css',
#   'https://www.mediamatters.org/sites/default/files/css/css_pY96yoZwW7Y-TMXHYh7SzaHemOMBGdzmMeteSMgje0U.css',
#   'https://www.mediamatters.org/steve-bannon/steve-bannon-and-matt-schlapp-say-e-jean-carroll-defamation-verdict-signals-end',
#   'https://www.mediamatters.org/steve-bannon/steve-bannon-democrats-need-phony-fake-voters-win-elections',
#   'https://www.mediamatters.org/studies',
#   'https://www.mediamatters.org/submissions',
#   'https://www.mediamatters.org/take-action',
#   'https://www.mediamatters.org/terms-conditions',
#   'https://www.mediamatters.org/themes/custom/mmfa_theme/favicon.ico',
#   'https://www.mediamatters.org/tiktok/tiktok-shop-selling-black-market-vapes-children',
#   'https://www.mediamatters.org/tim-pool/youtube-profiting-tim-pools-abhorrent-commentary-mass-shootings',
#   'https://www.mediamatters.org/voter-fraud-and-suppression/after-championing-return-abortion-policy-states-anti-abortion-figures',
#   'https://www.youtube.com/channel/UC_70iWZ6ym2cglS_kv5YfmA'},
#  {'https://1.1.1.1',
#   'https://1.1.1.1/#a',
#   'https://1.1.1.1/#b',
#   'https://1.1.1.1/ar-EG/',
#   'https://1.1.1.1/de-DE/',
#   'https://1.1.1.1/dns/',
#   'https://1.1.1.1/es-ES/',
#   'https://1.1.1.1/fa-IR/',
#   'https://1.1.1.1/family/',
#   'https://1.1.1.1/favicon.ico',
#   'https://1.1.1.1/fr-FR/',
#   'https://1.1.1.1/id-ID/',
#   'https://1.1.1.1/it-IT/',
#   'https://1.1.1.1/ja-JP/',
#   'https://1.1.1.1/ko-KR/',
#   'https://1.1.1.1/media/manifest.json',
#   'https://1.1.1.1/nl-NL/',
#   'https://1.1.1.1/pl-PL/',
#   'https://1.1.1.1/pt-BR/',
#   'https://1.1.1.1/ru-RU/',
#   'https://1.1.1.1/site-154bec96cd692fe98c89.css',
#   'https://1.1.1.1/tr-TR/',
#   'https://1.1.1.1/zh-Hans/',
#   'https://1.1.1.1/zh-Hant/',
#   'https://1111-releases.cloudflareclient.com/mac/Cloudflare_WARP.zip',
#   'https://1111-releases.cloudflareclient.com/windows/Cloudflare_WARP_Release-x64.msi',
#   'https://blog.cloudflare.com/warp-for-desktop',
#   'https://cloudflare.com',
#   'https://developers.cloudflare.com/warpclient/setting-up/linux/',
#   'https://developers.cloudflare.com/warpclient/setting-up/macOS/',
#   'https://developers.cloudflare.com/warpclient/setting-up/windows/',
#   'https://itunes.apple.com/us/app/1-1-1-1-faster-internet/id1423538627',
#   'https://pkg.cloudflareclient.com/',
#   'https://play.google.com/store/apps/details?id=com.cloudflare.onedotonedotonedotone',
#   'https://twitter.com/intent/tweet?text=ISPs%20spy%20on%20your%20Internet%20traffic%20and%20sell%20the%20data.%20I%27m%20using%201.1.1.1%20with%20WARP%2C%20a%20free%20app%20which%20makes%20the%20Internet%20on%20my%20phone%20faster%20and%20more%20private.%20You%20should%20get%20the%20app%20too%3A%20https%3A//one.one.one.one',
#   'https://www.cloudflare.com/careers/departments/'},
#  {'http://edition.pagesuite-professional.co.uk/Launch.aspx?bypass=true&amp;PBID=74262970-aa07-44b3-80c8-21fa8a8ac376',
#   'http://www.powerjobs.com/',
#   'https://howfastcanwesolvealzheimers.splashthat.com/Newsletters',
#   'https://login.politico.com?redirect=https%3A%2F%2Fwww.politico.com%2Fsettings',
#   'https://policies.google.com/privacy',
#   'https://policies.google.com/terms',
#   'https://static.politico.com/cf/05/ee684a274496b04fa20ba2978da1/politico.png',
#   'https://static.politico.com/resource/0000017e-7fd1-d4e5-adfe-7ff9f1280001/styleguide/assets/css/style-core.js.b3d317efb1e60e48d6ec82b01927c270.gz.css',
#   'https://subscriber.politicopro.com/article/2024/01/cftcs-behnam-crypto-legislation-does-not-bring-legitimacy-00138139',
#   'https://twitter.com/intent/tweet?url=https://politi.co/47QDRKp&amp;text=An interview with Brian Moynihan&amp;via=politico',
#   'https://twitter.com/politico',
#   'https://www.bloomberg.com/news/articles/2024-01-28/hints-of-early-ecb-rate-cut-highlight-divisions-in-council?srnd=premium',
#   'https://www.eenews.net/',
#   'https://www.facebook.com/politico/',
#   'https://www.facebook.com/sharer/sharer.php?u=https://politi.co/47QDRKp',
#   'https://www.instagram.com/politico/',
#   'https://www.politico.com/',
#   'https://www.politico.com/2024-election/results/',
#   'https://www.politico.com/_logout?base=https%3A%2F%2Fwww.politico.com&amp;redirect=%2F_logout&amp;js=false',
#   'https://www.politico.com/about-us',
#   'https://www.politico.com/advertising',
#   'https://www.politico.com/android-chrome-192x192.png',
#   'https://www.politico.com/apple-touch-icon-114x114.png',
#   'https://www.politico.com/apple-touch-icon-120x120.png',
#   'https://www.politico.com/apple-touch-icon-144x144.png',
#   'https://www.politico.com/apple-touch-icon-152x152.png',
#   'https://www.politico.com/apple-touch-icon-180x180.png',
#   'https://www.politico.com/apple-touch-icon-60x60.png',
#   'https://www.politico.com/apple-touch-icon-72x72.png',
#   'https://www.politico.com/apple-touch-icon-76x76.png',
#   'https://www.politico.com/california',
#   'https://www.politico.com/cannabis',
#   'https://www.politico.com/careers',
#   'https://www.politico.com/cdn-cgi/l/email-protection#166c6177647b74647972625666797a7f627f75793875797b',
#   'https://www.politico.com/corrections',
#   'https://www.politico.com/dims4/default/27ede68/2147483647/legacy_thumbnail/72x72/quality/90/?url=https%3A%2F%2Fstatic.politico.com%2Fcf%2F05%2Fee684a274496b04fa20ba2978da1%2Fpolitico.png',
#   'https://www.politico.com/dims4/default/59ee5a3/2147483647/legacy_thumbnail/114x114/quality/90/?url=https%3A%2F%2Fstatic.politico.com%2Fcf%2F05%2Fee684a274496b04fa20ba2978da1%2Fpolitico.png',
#   'https://www.politico.com/dims4/default/bd69088/2147483647/legacy_thumbnail/144x144/quality/90/?url=https%3A%2F%2Fstatic.politico.com%2Fcf%2F05%2Fee684a274496b04fa20ba2978da1%2Fpolitico.png',
#   'https://www.politico.com/dims4/default/c73c7f7/2147483647/legacy_thumbnail/57x57/quality/90/?url=https%3A%2F%2Fstatic.politico.com%2Fcf%2F05%2Fee684a274496b04fa20ba2978da1%2Fpolitico.png',
#   'https://www.politico.com/education',
#   'https://www.politico.com/energy-and-environment',
#   'https://www.politico.com/faq',
#   'https://www.politico.com/favicon-16x16.png',
#   'https://www.politico.com/favicon-32x32.png',
#   'https://www.politico.com/favicon-96x96.png',
#   'https://www.politico.com/feedback',
#   'https://www.politico.com/finance',
#   'https://www.politico.com/gallery',
#   'https://www.politico.com/health-care',
#   'https://www.politico.com/interactives/2023/republican-candidates-2024-gop-presidential-hopefuls-list/',
#   'https://www.politico.com/live-events/previous',
#   'https://www.politico.com/live-events/upcoming',
#   'https://www.politico.com/live-updates/congress',
#   'https://www.politico.com/magazine',
#   'https://www.politico.com/manifest.json',
#   'https://www.politico.com/news/2024-elections',
#   'https://www.politico.com/news/2024/01/27/dozen-funding-totals-struck-as-congress-races-to-avert-another-shutdown-cliff-00138215',
#   'https://www.politico.com/news/2024/01/28/biden-trade-officials-jump-ship-00138117',
#   'https://www.politico.com/news/2024/01/28/gop-reaction-trump-carroll-verdict-00138230',
#   'https://www.politico.com/news/2024/01/28/meat-giant-deforestation-jbs-00137084',
#   'https://www.politico.com/news/2024/01/28/republicans-split-jordan-attacks-carlson-00138272',
#   'https://www.politico.com/news/2024/01/29/mcconnell-johnson-trump-border-ukraine-deal-00138165',
#   'https://www.politico.com/news/compass',
#   'https://www.politico.com/news/elections',
#   'https://www.politico.com/news/florida',
#   'https://www.politico.com/news/foreign-affairs',
#   'https://www.politico.com/news/fourth-estate',
#   'https://www.politico.com/news/immigration',
#   'https://www.politico.com/news/magazine/2024/01/28/a-trump-dictatorship-is-possible-but-not-in-four-years-00137949',
#   'https://www.politico.com/news/matt-wuerker',
#   'https://www.politico.com/news/new-jersey',
#   'https://www.politico.com/news/new-york',
#   'https://www.politico.com/news/rich-lowry',
#   'https://www.politico.com/news/sustainability',
#   'https://www.politico.com/newsletters',
#   'https://www.politico.com/newsletters/inside-congress',
#   'https://www.politico.com/newsletters/morning-money',
#   'https://www.politico.com/newsletters/morning-money/2024/01/16/sleeper-risks-in-2024-00135630',
#   'https://www.politico.com/newsletters/morning-money/2024/01/23/crypto-strikes-back-00137121',
#   'https://www.politico.com/newsletters/morning-money/2024/01/24/joe-manchins-debt-crusade-00137447',
#   'https://www.politico.com/newsletters/morning-money/2024/01/25/bidens-gamble-00137750',
#   'https://www.politico.com/newsletters/morning-money/2024/01/26/wall-streets-trump-conundrum-00138037',
#   'https://www.politico.com/newsletters/morning-money/2024/01/29/a-q-a-with-brian-moynihan-00138284',
#   'https://www.politico.com/newsletters/morning-money/archive',
#   'https://www.politico.com/newsletters/newyorkplaybook?cid=mkt_NYPB_NLs',
#   'https://www.politico.com/newsletters/playbook-pm',
#   'https://www.politico.com/newsletters/politico-nightly',
#   'https://www.politico.com/newsletters/politico-weekend',
#   'https://www.politico.com/newsletters/the-recast',
#   'https://www.politico.com/newsletters/west-wing-playbook',
#   'https://www.politico.com/payment',
#   'https://www.politico.com/playbook',
#   'https://www.politico.com/podcasts',
#   'https://www.politico.com/politics',
#   'https://www.politico.com/press/about',
#   'https://www.politico.com/privacy',
#   'https://www.politico.com/privacy-policy',
#   'https://www.politico.com/rss',
#   'https://www.politico.com/rss/politicopicks.xml',
#   'https://www.politico.com/series/states/the-fifty',
#   'https://www.politico.com/settings',
#   'https://www.politico.com/sitemap',
#   'https://www.politico.com/staff/zachary-warmbrodt',
#   'https://www.politico.com/story/2018/07/09/banks-lobbying-donald-trump-669706',
#   'https://www.politico.com/subscribe/breaking-news-alerts',
#   'https://www.politico.com/subscriptions',
#   'https://www.politico.com/tag/agriculture',
#   'https://www.politico.com/tag/altitude',
#   'https://www.politico.com/tag/capital-city',
#   'https://www.politico.com/tag/cartoon-carousel',
#   'https://www.politico.com/tag/column-on-politics',
#   'https://www.politico.com/tag/column-tomorrow',
#   'https://www.politico.com/tag/cybersecurity',
#   'https://www.politico.com/tag/defense',
#   'https://www.politico.com/tag/labor',
#   'https://www.politico.com/tag/legal',
#   'https://www.politico.com/tag/pro-canada',
#   'https://www.politico.com/technology',
#   'https://www.politico.com/terms-of-service',
#   'https://www.politico.com/tipsheets/morning-money',
#   'https://www.politico.com/tipsheets/morning-money#icon-search',
#   'https://www.politico.com/tipsheets/morning-money?tab=most-read',
#   'https://www.politico.com/trade',
#   'https://www.politico.com/transportation',
#   'https://www.politico.com/video',
#   'https://www.politico.com/white-house',
#   'https://www.politico.com/womenrule',
#   'https://www.politico.com/write-for-us',
#   'https://www.politico.eu',
#   'https://www.politico.eu/uk',
#   'https://www.politicopro.com/',
#   'https://www.politicopro.com/pro-reporting/?cid=promkt_20q1_corenews_act_money',
#   'https://www.washingtonpost.com/business/2024/01/28/global-economy-gdp-inflation/',
#   'https://www.wsj.com/economy/central-banking/plummeting-inflation-raises-new-risk-for-fed-rising-real-interest-rates-fd2a4f37?mod=hp_lead_pos5',
#   'javascript:void(0)'},
#  {'https://www.bloomberg.com/feedback',
#   'https://www.bloomberg.com/notices/tos'},
#  set()]

# %%
loop.

# %%
z = await asyncio.gather(*tasks)

# %%
len(z), len(urls)
# Out:
# (8, 8)
