# %%
from datasets import load_dataset
ds = load_dataset('shunk031/MSCOCO')
# Out:
# ...
# Generating train split: 82783 examples [00:33, 2460.61 examples/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /mnt/ssd3/user/spock/.cache/pypoetry/virtualenvs/ai-iwSNfyWa-py3.10/lib/python3.10/site-packages/datasets/builder.py:1973, in ArrowBasedBuilder._prepare_split_single(self, gen_kwargs, fpath, file_format, max_shard_size, job_id)
#    1972 _time = time.time()
# -> 1973 for _, table in generator:
#    1974     if max_shard_size is not None and writer._num_bytes > max_shard_size:
#
# File /mnt/ssd3/user/spock/.cache/pypoetry/virtualenvs/ai-iwSNfyWa-py3.10/lib/python3.10/site-packages/datasets/packaged_modules/parquet/parquet.py:94, in Parquet._generate_tables(self, files)
#      91         # Uncomment for debugging (will print the Arrow table size and elements)
#      92         # logger.warning(f"pa_table: {pa_table} num rows: {pa_table.num_rows}")
# ...
